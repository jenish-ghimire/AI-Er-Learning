# %%
# Predict per capita income (US$) for the year 2020 using linear regression.
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"D:\Carrer\AI\AI Er Learning\ML\1) Linear_Regression_Single_Variable\data\canada_per_capita_income.csv")
print('Programmed by: Jenish Ghimire')
df.head(10)
# Out:
# Programmed by: Jenish Ghimire
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583
# 5  1975              5998.144346
# 6  1976              7062.131392
# 7  1977              7100.126170
# 8  1978              7247.967035
# 9  1979              7602.912681

# %%
# prediction for the year 2020
from sklearn.metrics import mean_squared_error
import numpy as np
reg = linear_model.LinearRegression()
reg.fit(df[['year']],df['per capita income (US$)'])
predict_df = pd.DataFrame([2020],columns=['year'])
predict = reg.predict(predict_df[['year']])
y_actual = df['per capita income (US$)']
y_predicted = reg.predict(df[['year']])
rmse = np.sqrt(mean_squared_error(y_actual,y_predicted))
print('Programmed by: Jenish Ghimire')
print(f'Predicted value for 2020 = {predict}')
print(f'Slope(m) = {reg.coef_} and Intercept = {reg.intercept_}')
print(f'Root Mean Square Error = {rmse}')
# Out:
# Programmed by: Jenish Ghimire
# Predicted value for 2020 = [41288.69409442]
# Slope(m) = [828.46507522] and Intercept = -1632210.7578554575
# Root Mean Square Error = 3932.268945723928

# %%
# plotting the linear regression 
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df['year'],df['per capita income (US$)'],color='green')
plt.plot(df['year'],reg.predict(df[['year']]))
print('Programmed by: Jenish Ghimire')
plt.savefig(r'D:\Carrer\AI\AI Er Learning\ML\1) Linear_Regression_Single_Variable\images\linear_regression_plot.png')
# Out:
# Programmed by: Jenish Ghimire
